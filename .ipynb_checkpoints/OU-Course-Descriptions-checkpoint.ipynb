# %% [markdown]
# # OU Course Descriptions
# This script is designed to scrap the 2018-2019 course descriptions off this website: http://ou-public.courseleaf.com/courses/.

# %%
#Import Libraries
from bs4 import BeautifulSoup 
import requests
import re
import csv

# %%
#Grab data from url and parse into HTML elements using BS
r = requests.get('http://ou-public.courseleaf.com/courses/')
soup=BeautifulSoup(r.text, 'html.parser')

# %%
#Finding all the links on the page
links = soup.find_all('a')
#Saving links to pages of descriptions as pages
pages = links[69:-14]

# %%
#Creating Lists for Data
unique_ids = ['Unique_ID']
titles = ['Title']
numbers = ['Number']
credits = ['Credits']
descriptions =['Description']
departments = ['Department']

#Loop that goes through each departments page and pull relevant info
for link in pages:
    url = 'http://ou-public.courseleaf.com' + str(link.get('href'))
    page_r = requests.get(url)
    page_soup=BeautifulSoup(page_r.text, 'html.parser')
    print('Scraped data from: ',url)
    #Go through the courseblock title noindent field to pull out data
    for item in page_soup.find_all('p', class_="courseblocktitle noindent"):
        #Get department from url and append
        department = link.get('href')[9:-1]
        departments.append(department)
        #Splits the p block at each .
        list_url = item.get_text().split('.')
        #appends the approriate split sections into the correct list
        numbers.append(list_url[0][-4:].strip())
        titles.append(list_url[1].strip())
        unique_ids.append(link.get('href')[9:-1] + '-' + list_url[0][-4:].strip())
    
    #Grab and append each credit hour field
    for item in page_soup.findAll('span', class_="credits"):
        credits.append(item.get_text())
    
    #Grab and append each course description
    for item in page_soup.findAll('p', class_="courseblockdesc"):
        descriptions.append(item.get_text(strip="TRUE"))
print('Done Scraping!')
# Out:
# Scraped data from:  http://ou-public.courseleaf.com/courses/a_hi/
# Scraped data from:  http://ou-public.courseleaf.com/courses/acct/
# Scraped data from:  http://ou-public.courseleaf.com/courses/aero/
# Scraped data from:  http://ou-public.courseleaf.com/courses/afam/
# Scraped data from:  http://ou-public.courseleaf.com/courses/agsc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ahs/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ame/
# Scraped data from:  http://ou-public.courseleaf.com/courses/amgt/
# Scraped data from:  http://ou-public.courseleaf.com/courses/anth/
# Scraped data from:  http://ou-public.courseleaf.com/courses/arab/
# Scraped data from:  http://ou-public.courseleaf.com/courses/arch/
# Scraped data from:  http://ou-public.courseleaf.com/courses/arnm/
# Scraped data from:  http://ou-public.courseleaf.com/courses/art/
# Scraped data from:  http://ou-public.courseleaf.com/courses/artc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/arth/
# Scraped data from:  http://ou-public.courseleaf.com/courses/astr/
# Scraped data from:  http://ou-public.courseleaf.com/courses/atc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/avia/
# Scraped data from:  http://ou-public.courseleaf.com/courses/b_ad/
# Scraped data from:  http://ou-public.courseleaf.com/courses/b_c/
# Scraped data from:  http://ou-public.courseleaf.com/courses/basn/
# Scraped data from:  http://ou-public.courseleaf.com/courses/bass/
# Scraped data from:  http://ou-public.courseleaf.com/courses/biol/
# Scraped data from:  http://ou-public.courseleaf.com/courses/bme/
# Scraped data from:  http://ou-public.courseleaf.com/courses/c_s/
# Scraped data from:  http://ou-public.courseleaf.com/courses/cas/
# Scraped data from:  http://ou-public.courseleaf.com/courses/cee/
# Scraped data from:  http://ou-public.courseleaf.com/courses/cees/
# Scraped data from:  http://ou-public.courseleaf.com/courses/celo/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ch_e/
# Scraped data from:  http://ou-public.courseleaf.com/courses/chem/
# Scraped data from:  http://ou-public.courseleaf.com/courses/cher/
# Scraped data from:  http://ou-public.courseleaf.com/courses/chey/
# Scraped data from:  http://ou-public.courseleaf.com/courses/chin/
# Scraped data from:  http://ou-public.courseleaf.com/courses/choc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/cl_c/
# Scraped data from:  http://ou-public.courseleaf.com/courses/clar/
# Scraped data from:  http://ou-public.courseleaf.com/courses/cns/
# Scraped data from:  http://ou-public.courseleaf.com/courses/comm/
# Scraped data from:  http://ou-public.courseleaf.com/courses/comp/
# Scraped data from:  http://ou-public.courseleaf.com/courses/crek/
# Scraped data from:  http://ou-public.courseleaf.com/courses/danc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/deng/
# Scraped data from:  http://ou-public.courseleaf.com/courses/des/
# Scraped data from:  http://ou-public.courseleaf.com/courses/dmat/
# Scraped data from:  http://ou-public.courseleaf.com/courses/dram/
# Scraped data from:  http://ou-public.courseleaf.com/courses/drdg/
# Scraped data from:  http://ou-public.courseleaf.com/courses/dsa/
# Scraped data from:  http://ou-public.courseleaf.com/courses/eacs/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ece/
# Scraped data from:  http://ou-public.courseleaf.com/courses/econ/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edah/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edec/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edel/
# Scraped data from:  http://ou-public.courseleaf.com/courses/eden/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edlt/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edma/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edpc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edpr/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edpy/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edrg/
# Scraped data from:  http://ou-public.courseleaf.com/courses/eds/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edsc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edse/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edsp/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edss/
# Scraped data from:  http://ou-public.courseleaf.com/courses/educ/
# Scraped data from:  http://ou-public.courseleaf.com/courses/edwl/
# Scraped data from:  http://ou-public.courseleaf.com/courses/eipt/
# Scraped data from:  http://ou-public.courseleaf.com/courses/emba/
# Scraped data from:  http://ou-public.courseleaf.com/courses/emgt/
# Scraped data from:  http://ou-public.courseleaf.com/courses/en_d/
# Scraped data from:  http://ou-public.courseleaf.com/courses/engb/
# Scraped data from:  http://ou-public.courseleaf.com/courses/engl/
# Scraped data from:  http://ou-public.courseleaf.com/courses/engr/
# Scraped data from:  http://ou-public.courseleaf.com/courses/enst/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ent/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ephy/
# Scraped data from:  http://ou-public.courseleaf.com/courses/euph/
# Scraped data from:  http://ou-public.courseleaf.com/courses/expo/
# Scraped data from:  http://ou-public.courseleaf.com/courses/f_a/
# Scraped data from:  http://ou-public.courseleaf.com/courses/fin/
# Scraped data from:  http://ou-public.courseleaf.com/courses/flut/
# Scraped data from:  http://ou-public.courseleaf.com/courses/fms/
# Scraped data from:  http://ou-public.courseleaf.com/courses/fr_h/
# Scraped data from:  http://ou-public.courseleaf.com/courses/fr/
# Scraped data from:  http://ou-public.courseleaf.com/courses/fran/
# Scraped data from:  http://ou-public.courseleaf.com/courses/g_e/
# Scraped data from:  http://ou-public.courseleaf.com/courses/gcre/
# Scraped data from:  http://ou-public.courseleaf.com/courses/gdma/
# Scraped data from:  http://ou-public.courseleaf.com/courses/geog/
# Scraped data from:  http://ou-public.courseleaf.com/courses/geol/
# Scraped data from:  http://ou-public.courseleaf.com/courses/germ/
# Scraped data from:  http://ou-public.courseleaf.com/courses/gis/
# Scraped data from:  http://ou-public.courseleaf.com/courses/gmer/
# Scraped data from:  http://ou-public.courseleaf.com/courses/gphy/
# Scraped data from:  http://ou-public.courseleaf.com/courses/grad/
# Scraped data from:  http://ou-public.courseleaf.com/courses/grk/
# Scraped data from:  http://ou-public.courseleaf.com/courses/grre/
# Scraped data from:  http://ou-public.courseleaf.com/courses/gtar/
# Scraped data from:  http://ou-public.courseleaf.com/courses/h_r/
# Scraped data from:  http://ou-public.courseleaf.com/courses/harp/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hcb/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hebr/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hes/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hist/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hms/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hon/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hpcd/
# Scraped data from:  http://ou-public.courseleaf.com/courses/hsci/
# Scraped data from:  http://ou-public.courseleaf.com/courses/i_d/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ias/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ilac/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ilaw/
# Scraped data from:  http://ou-public.courseleaf.com/courses/intl/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ise/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ital/
# Scraped data from:  http://ou-public.courseleaf.com/courses/japn/
# Scraped data from:  http://ou-public.courseleaf.com/courses/jmc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/jrre/
# Scraped data from:  http://ou-public.courseleaf.com/courses/kiow/
# Scraped data from:  http://ou-public.courseleaf.com/courses/l_a/
# Scraped data from:  http://ou-public.courseleaf.com/courses/l_s/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lat/
# Scraped data from:  http://ou-public.courseleaf.com/courses/law/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ldma/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lgbt/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ling/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lis/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lsal/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lscj/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lscs/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lsha/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lsis/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lslc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lsms/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lsps/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lsrl/
# Scraped data from:  http://ou-public.courseleaf.com/courses/lstd/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ltrs/
# Scraped data from:  http://ou-public.courseleaf.com/courses/m_s/
# Scraped data from:  http://ou-public.courseleaf.com/courses/math/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mbio/
# Scraped data from:  http://ou-public.courseleaf.com/courses/metr/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mgt/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mis/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mit/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mkt/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mlll/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mrs/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mthr/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mued/
# Scraped data from:  http://ou-public.courseleaf.com/courses/muhi/
# Scraped data from:  http://ou-public.courseleaf.com/courses/muli/
# Scraped data from:  http://ou-public.courseleaf.com/courses/munm/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mus/
# Scraped data from:  http://ou-public.courseleaf.com/courses/musc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mute/
# Scraped data from:  http://ou-public.courseleaf.com/courses/muth/
# Scraped data from:  http://ou-public.courseleaf.com/courses/mutk/
# Scraped data from:  http://ou-public.courseleaf.com/courses/n_s/
# Scraped data from:  http://ou-public.courseleaf.com/courses/nas/
# Scraped data from:  http://ou-public.courseleaf.com/courses/npng/
# Scraped data from:  http://ou-public.courseleaf.com/courses/oboe/
# Scraped data from:  http://ou-public.courseleaf.com/courses/odyn/
# Scraped data from:  http://ou-public.courseleaf.com/courses/orgn/
# Scraped data from:  http://ou-public.courseleaf.com/courses/p_e/
# Scraped data from:  http://ou-public.courseleaf.com/courses/p_sc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/pbio/
# Scraped data from:  http://ou-public.courseleaf.com/courses/pcus/
# Scraped data from:  http://ou-public.courseleaf.com/courses/pdc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/pers/
# Scraped data from:  http://ou-public.courseleaf.com/courses/phch/
# Scraped data from:  http://ou-public.courseleaf.com/courses/phil/
# Scraped data from:  http://ou-public.courseleaf.com/courses/phys/
# Scraped data from:  http://ou-public.courseleaf.com/courses/pian/
# Scraped data from:  http://ou-public.courseleaf.com/courses/port/
# Scraped data from:  http://ou-public.courseleaf.com/courses/psy/
# Scraped data from:  http://ou-public.courseleaf.com/courses/rcpl/
# Scraped data from:  http://ou-public.courseleaf.com/courses/rels/
# Scraped data from:  http://ou-public.courseleaf.com/courses/rphd/
# Scraped data from:  http://ou-public.courseleaf.com/courses/russ/
# Scraped data from:  http://ou-public.courseleaf.com/courses/s_wk/
# Scraped data from:  http://ou-public.courseleaf.com/courses/sax/
# Scraped data from:  http://ou-public.courseleaf.com/courses/scm/
# Scraped data from:  http://ou-public.courseleaf.com/courses/soc/
# Scraped data from:  http://ou-public.courseleaf.com/courses/span/
# Scraped data from:  http://ou-public.courseleaf.com/courses/srre/
# Scraped data from:  http://ou-public.courseleaf.com/courses/tcom/
# Scraped data from:  http://ou-public.courseleaf.com/courses/trmp/
# Scraped data from:  http://ou-public.courseleaf.com/courses/trom/
# Scraped data from:  http://ou-public.courseleaf.com/courses/tuba/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ucol/
# Scraped data from:  http://ou-public.courseleaf.com/courses/ugre/
# Scraped data from:  http://ou-public.courseleaf.com/courses/univ/
# Scraped data from:  http://ou-public.courseleaf.com/courses/vioa/
# Scraped data from:  http://ou-public.courseleaf.com/courses/viol/
# Scraped data from:  http://ou-public.courseleaf.com/courses/voic/
# Scraped data from:  http://ou-public.courseleaf.com/courses/wgs/
# Done Scraping!

# %%
with open('data.csv','w') as outfile:
    rowlists = zip(unique_ids,departments,numbers,titles, credits, descriptions)
    writer = csv.writer(outfile)
    for row in rowlists:
        writer.writerows([row])
print('Saved CSV file of courses')
# Out:
# Saved CSV file of courses

# %%
import pandas as pd
#Creating Dataframe from lists
courses = pd.DataFrame(
    {'Title': titles[1:] ,
     'Number': numbers[1:],
     'Credits': credits[1:],
     'Description': descriptions[1:],
     'Departments': departments[1:],
     'Unique_ID' : unique_ids[1:]
    })
#Setting to index by Unique_IDs
courses.set_index('Unique_ID')
#Display first 5 lines
courses.head(n=5)
# Out:
#              Credits Departments  \
# 0    3 Credit Hours.        a_hi
# 1    4 Credit Hours.        a_hi
# 2    3 Credit Hours.        a_hi
# 3    3 Credit Hours.        a_hi
# 4  2-6 Credit Hours.        a_hi
#
#                                          Description Number  \
# 0  Explanation and analysis of the principles und...   1113
# 1  Students will be introduced to basic concepts ...   2014
# 2  The visual arts from the prehistoric through t...   2213
# 3  The visual arts from the Renaissance to the pr...   2223
# 4  2-6 hours.; Prerequisite:  Permission of instr...   2930
#
#                          Title  Unique_ID
# 0     The Understanding of Art  a_hi-1113
# 1  Introduction to Art History  a_hi-2014
# 2                 Global Art I  a_hi-2213
# 3                Global Art II  a_hi-2223
# 4               Special Topics  a_hi-2930

# %%
def search_courses(term):
    results = courses[courses.Description.str.contains(term)]
    print(str(len(results)), 'courses found', '\n')
    print('From the following', str(len(results.Departments.unique())), 'departments:', 
          results.Departments.unique(), '\n')
    response = input('Would you like to save the result to a csv? ')
    print('\n')
    if response.lower() == "yes" or response.lower() == "y":
        results.to_csv("results/"+ term +".csv")
        print('Saved result to csv as '+ term + ".csv in the results folder.", '\n')
    else:
        print('Did not save results to csv, but preview is available below.')
    return results

# %%
#Example of searching course descriptions for key terms
search_courses('digital')
# Out:
# 72 courses found
#
# From the following 26 departments: ['a_hi' 'afam' 'ame' 'arch' 'art' 'artc' 'atc' 'cas' 'cees' 'ch_e' 'ece'
#  'edrg' 'engl' 'engr' 'fms' 'geog' 'gis' 'hsci' 'jmc' 'lis' 'lscj' 'metr'
#  'mis' 'mutk' 'p_e' 'phys']
#
# Would you like to save the result to a csv? n
#
#
# Did not save results to csv, but preview is available below.
#               Credits Departments  \
# 17    3 Credit Hours.        a_hi
# 23    3 Credit Hours.        a_hi
# 180   3 Credit Hours.        afam
# 248   3 Credit Hours.         ame
# 264   3 Credit Hours.         ame
# 566   5 Credit Hours.        arch
# 606   3 Credit Hours.        arch
# 644   3 Credit Hours.        arch
# 691   3 Credit Hours.         art
# 697   3 Credit Hours.         art
# 708   3 Credit Hours.         art
# 710   3 Credit Hours.         art
# 712   3 Credit Hours.         art
# 714   3 Credit Hours.         art
# 718   3 Credit Hours.         art
# 739   3 Credit Hours.         art
# 744   3 Credit Hours.         art
# 896   3 Credit Hours.        artc
# 961   3 Credit Hours.         atc
# 1365  2 Credit Hours.         cas
# 1430  3 Credit Hours.        cees
# 1523  3 Credit Hours.        ch_e
# 1528  3 Credit Hours.        ch_e
# 2250  3 Credit Hours.         ece
# 2251  3 Credit Hours.         ece
# 2260  3 Credit Hours.         ece
# 2262  3 Credit Hours.         ece
# 2280  3 Credit Hours.         ece
# 2303  3 Credit Hours.         ece
# 2305  3 Credit Hours.         ece
# ...               ...         ...
# 3820  3 Credit Hours.        geog
# 3997  3 Credit Hours.         gis
# 4009  3 Credit Hours.         gis
# 4607  3 Credit Hours.        hsci
# 4618  3 Credit Hours.        hsci
# 4619  3 Credit Hours.        hsci
# 4628   1 Credit Hour.        hsci
# 4629  3 Credit Hours.        hsci
# 4630  3 Credit Hours.        hsci
# 5035  3 Credit Hours.         jmc
# 5064  3 Credit Hours.         jmc
# 5106  3 Credit Hours.         jmc
# 5132  3 Credit Hours.         jmc
# 5170  3 Credit Hours.         jmc
# 5454  3 Credit Hours.         lis
# 5480  3 Credit Hours.         lis
# 5481  3 Credit Hours.         lis
# 5485  3 Credit Hours.         lis
# 5488  3 Credit Hours.         lis
# 5492  3 Credit Hours.         lis
# 5505  3 Credit Hours.         lis
# 5611  3 Credit Hours.        lscj
# 6139  3 Credit Hours.        metr
# 6143  3 Credit Hours.        metr
# 6230  3 Credit Hours.         mis
# 6766  3 Credit Hours.        mutk
# 6767  3 Credit Hours.        mutk
# 6771  3 Credit Hours.        mutk
# 6917  3 Credit Hours.         p_e
# 7363  3 Credit Hours.        phys
#
#                                             Description Number  \
# 17    Prerequisite: Junior standing. This course cov...   3693
# 23    Prerequisites: junior standing. Explores appro...   3913
# 180   This course focuses on the issue of the digita...   2913
# 248   Prerequisite:PHYS 2514;MATH 1823or1914;MATH 24...   2623
# 264   Prerequisites:AME 2402orCH E 2002or ENGR 2003 ...   3723
# 566   Prerequisite: Co-requisites:ARCH 1163or permis...   1155
# 606   (Slashlisted withARCH 5773) Prerequisite: seni...   4773
# 644   (Slashlisted withARCH 4773) Prerequisite: Grad...   5773
# 691   Prerequisites: majors only;ART 1033andART 1043...   2533
# 697   Prerequisite: majors only; ART 1013, ART 1023,...   2873
# 708   Prerequisites: majors only; junior standing;AR...   3533
# 710   Prerequisites: majors only; junior standing;AR...   3563
# 712   Prerequisite: majors only;ART 2743. May be rep...   3753
# 714   Prerequisite: 2813. Continuation of Filmmaking...   3813
# 718   Prerequisite: majors only; Art 2853. Explores ...   3863
# 739   Prerequisite: 3810 or 3873. May be repeated wi...   4813
# 744   Prerequisite: majors only;ART 2853orATC 2853an...   4863
# 896   Prerequisite:ENGL 1213. An introduction to the...   2813
# 961   Prerequisite: Majors only;ART 1033andART 1043....   2823
# 1365  Prerequisite: junior standing or permission of...   3002
# 1430  Prerequisites:CEES 2213,CEES 3403andMATH 2433o...   4453
# 1523  Prerequisites: CHE 2002 (or concurrent enrollm...   3723
# 1528  Prerequisite: 4473. Formulation of first-order...   4153
# 2250  (Slashlisted with 5213) Prerequisite: 3793.  D...   4213
# 2251  Prerequisites:ECE 3223andECE 3873. Design of d...   4273
# 2260  (Slashlisted with 5623) Prerequisite: 3223.  D...   4623
# 2262  (Slashlisted withECE 5653) Prerequisite:ECE 37...   4653
# 2280  (Slashlisted with 4213) Prerequisite: 3793. Di...   5213
# 2303  (Slashlisted with 4623) Prerequisite: 3223. De...   5623
# 2305  (Slashlisted withECE 4653). Prerequisite:ECE 3...   5653
# ...                                                 ...    ...
# 3820  (Slashlisted withGEOG 4123) Prerequisite: Grad...   5123
# 3997  (Slashlisted with 5233) Prerequisite: Grade of...   4233
# 4009  (Slashlisted with 4233) Prerequisite: Graduate...   5233
# 4607  Prerequisite: junior standing, or completion o...   3493
# 4618  (Slashlisted withHSCI 5613) Prerequisite: juni...   4613
# 4619  (Slashlisted withHSCI 5623) Prerequisite: juni...   4623
# 4628  Prerequisite: graduate standing or permission ...   5601
# 4629  (Slashlisted withHSCI 4613) Prerequisite: grad...   5613
# 4630  (Slashlisted withHSCI 4623) Prerequisite: grad...   5623
# 5035  Prerequisite:JMC 1013,JMC 2033,JMC 3303,JMC 33...   3383
# 5064  (Slashlisted withJMC 5193) Prerequisite:JMC 10...   4193
# 5106  (Slashlisted with 5773) Prerequisite: 3613. Pr...   4773
# 5132  (Slashlisted withJMC 4193) Prerequisite:JMC 10...   5193
# 5170  (Slashlisted with 4773) Prerequisite: graduate...   5773
# 5454  (Slashlisted withLIS 5453) Prerequisite: junio...   4453
# 5480  Prerequisite:LIS 5033. Course covers childhood...   5183
# 5481  Prerequisite:LIS 5033. Covers developmental ch...   5193
# 5485  Prerequisite:LIS 5033or permission of school. ...   5233
# 5488  Prerequisite:LIS 5033. Introduction to the pri...   5343
# 5492  (Slashlisted withLIS 4453) Prerequisite:LIS 50...   5453
# 5505  Prerequisite: graduate standing andLIS 5033. T...   5653
# 5611  Prerequisite: junior standing or permission fr...   4423
# 6139  (Slashlisted with 4603) Prerequisite: Mathemat...   5603
# 6143  (Crosslisted withECE 5673) Prerequisite: grade...   5673
# 6230  Prerequisite: Student must be approved for deg...   4313
# 6766  Prerequisite: sophomore, junior, or senior sta...   4133
# 6767  Prerequisite: 4133. Advanced methods and theor...   4143
# 6771  Prerequisite: sophomore, junior, or senior sta...   4183
# 6917  Prerequisite:MATH 3113orMATH 3413or concurrent...   3723
# 7363  Prerequisite: 1215 or 2524 (or concurrent enro...   2303
#
#                                                   Title  Unique_ID
# 17                                        New Media Art  a_hi-3693
# 23                              American Visual Culture  a_hi-3913
# 180   Perspectives on the Digital Divide: Theory and...  afam-2913
# 248                                Circuits and Sensors   ame-2623
# 264       Numerical Methods For Engineering Computation   ame-3723
# 566                       Design I- Design Fundamentals  arch-1155
# 606                Computational Design and Fabrication  arch-4773
# 644                Computational Design and Fabrication  arch-5773
# 691             Sculpture: Material, Space, and Process   art-2533
# 697                              Video for the Artist I   art-2873
# 708   Sculpture: Digital Fabrication for Artists and...   art-3533
# 710                 Sculpture: Functional Design Studio   art-3563
# 712                         Intermediate Printmaking II   art-3753
# 714                                       Filmmaking II   art-3813
# 718                    Intermediate Digital Photography   art-3863
# 739                           Media Arts Special Topics   art-4813
# 744                         Alternative Photo Practices   art-4863
# 896   Introduction to Visual Culture and Media Literacy  artc-2813
# 961                Space - Introductory Studio Practice   atc-2823
# 1365                     Digital Scholarship Internship   cas-3002
# 1430                              Geomatics Engineering  cees-4453
# 1523      Numerical Methods for Engineering Computation  ch_e-3723
# 1528                       Process Dynamics and Control  ch_e-4153
# 2250                          Digital Signal Processing   ece-4213
# 2251                          Digital Design Laboratory   ece-4273
# 2260                           Computer Hardware Design   ece-4623
# 2262                              Digital Radar Systems   ece-4653
# 2280                          Digital Signal Processing   ece-5213
# 2303                           Computer Hardware Design   ece-5623
# 2305                              Digital Radar Systems   ece-5653
# ...                                                 ...        ...
# 3820                                    Urban Geography  geog-5123
# 3997                           Digital Image Processing   gis-4233
# 4009                           Digital Image Processing   gis-5233
# 4607                               The History of Media  hsci-3493
# 4618       Issues and Methods in the Digital Humanities  hsci-4613
# 4619     Practicum/Internship in the Digital Humanities  hsci-4623
# 4628               Digital Humanities Online Colloquium  hsci-5601
# 4629       Issues and Methods in the Digital Humanities  hsci-5613
# 4630     Practicum/Internship in the Digital Humanities  hsci-5623
# 5035                                  Digital Design II   jmc-3383
# 5064               Principles of Media Entrepreneurship   jmc-4193
# 5106                       Post Production and Graphics   jmc-4773
# 5132               Principles of Media Entrepreneurship   jmc-5193
# 5170                       Post Production and Graphics   jmc-5773
# 5454                                Digital Collections   lis-4453
# 5480    Information Resources and Services for Children   lis-5183
# 5481  Information Resources and Services for Young A...   lis-5193
# 5485                   Oklahoma Information Environment   lis-5233
# 5488                   Archival Concepts and Traditions   lis-5343
# 5492                                Digital Collections   lis-5453
# 5505              Preservation of Information Materials   lis-5653
# 5611                                Cyberspace Security  lscj-4423
# 6139                   Micrometeorological Measurements  metr-5603
# 6143                  Weather Radar Theory and Practice  metr-5673
# 6230                 Introduction to Business Analytics   mis-4313
# 6766          Introduction to Digital Signal Processing  mutk-4133
# 6767                 Advanced Digital Signal Processing  mutk-4143
# 6771                                       Sound Design  mutk-4183
# 6917      Numerical Methods for Engineering Computation   p_e-3723
# 7363                                        Electronics  phys-2303
#
# [72 rows x 6 columns]

# %%
#To search two differnt terms use the | symbol
search_courses('innovation|innovative')
# Out:
# 33 courses found
#
# From the following 19 departments: ['a_hi' 'ame' 'anth' 'arch' 'b_ad' 'econ' 'edah' 'edsp' 'engl' 'engr'
#  'ent' 'geog' 'h_r' 'hist' 'jmc' 'law' 'lsal' 'mkt' 'psy']
#
# Would you like to save the result to a csv? n
#
#
# Did not save results to csv, but preview is available below.
#                 Credits Departments  \
# 38      3 Credit Hours.        a_hi
# 72      3 Credit Hours.        a_hi
# 278     3 Credit Hours.         ame
# 310     3 Credit Hours.         ame
# 413     3 Credit Hours.        anth
# 618     5 Credit Hours.        arch
# 649     5 Credit Hours.        arch
# 654     6 Credit Hours.        arch
# 668     6 Credit Hours.        arch
# 1044    0 Credit Hours.        b_ad
# 1053    0 Credit Hours.        b_ad
# 1058    2 Credit Hours.        b_ad
# 2397    3 Credit Hours.        econ
# 2445    3 Credit Hours.        edah
# 2990    3 Credit Hours.        edsp
# 3371    3 Credit Hours.        engl
# 3400    3 Credit Hours.        engr
# 3401     1 Credit Hour.        engr
# 3471    3 Credit Hours.         ent
# 3474    3 Credit Hours.         ent
# 3476    3 Credit Hours.         ent
# 3477    3 Credit Hours.         ent
# 3755    3 Credit Hours.        geog
# 3777    3 Credit Hours.        geog
# 4108    3 Credit Hours.         h_r
# 4194    3 Credit Hours.         h_r
# 4399    3 Credit Hours.        hist
# 5116  1-3 Credit Hours.         jmc
# 5324    3 Credit Hours.         law
# 5536    3 Credit Hours.        lsal
# 5545    3 Credit Hours.        lsal
# 6284    3 Credit Hours.         mkt
# 7519    3 Credit Hours.         psy
#
#                                             Description Number  \
# 38    (Slashlisted with 5503) Prerequisite: junior s...   4503
# 72    (Slashlisted with 4503) Prerequisite: graduate...   5503
# 278   (Slashlisted withAME 5303) Prerequisite: All s...   4303
# 310   (Slashlisted withAME 4303) Prerequisite: Gradu...   5303
# 413   Prerequisite:ANTH 3203or permission of instruc...   4183
# 618   Prerequisite: ARCH 5922,ARCH 5955, or permissi...   5055
# 649   Prerequisite: ARCH 4823,ARCH 4855or permission...   5955
# 654   Prerequisite: Program admission or permission ...   6056
# 668   Prerequisite: Program admission or permission ...   6956
# 1044  Prerequisite: admission to full-time MBA progr...   5100
# 1053  Prerequisite: 5100, admission to full-time MBA...   5200
# 1058  Prerequisite: graduate standing and department...   5822
# 2397  Prerequisite: 6343. Examines advanced topics i...   6373
# 2445  Prerequisite: graduate standing. Designed to p...   5493
# 2990  Prerequisite: Graduate standing. Focus will be...   5183
# 3371  Prerequisite: graduate standing and permission...   6113
# 3400  Prerequisites: sophomore standing, junior stan...   4023
# 3401  Prerequisite: Junior standing or instructor pe...   4051
# 3471  Explore the basic concepts of innovation and e...   2113
# 3474  Prerequisite: Student must be approved for deg...   3123
# 3476  Prerequisite: student must be approved for deg...   3203
# 3477  Prerequisite: Student must be approved for deg...   3413
# 3755  Introduction to reading, analyzing and interpr...   1113
# 3777  Definition and evaluation of mineral, agricult...   3563
# 4108  Prerequiste:3013 or junior standing, or permis...   3203
# 4194  Prerequisite: graduate standing or permission ...   5713
# 4399  Prerequisite:HIST 1483,HIST 1493, junior stand...   3093
# 5116  1 to 3 hours. Prerequisite: permission of inst...   4970
# 5324  Prerequisite:LAW 5433orLAW 5434. This course o...   5743
# 5536  Prerequisite: junior standing or permission fr...   3533
# 5545  Prerequisites: Sophomore standing andLSAL 4163...   4643
# 6284  Prerequisite: Student must be approved for deg...   3413
# 7519  Prerequisite: 5703. This graduate seminar exam...   6713
#
#                                                   Title  Unique_ID
# 38    Art of the 18th Century: The Age of Enlightenment  a_hi-4503
# 72    Art of the 18th Century: The Age of Enlightenment  a_hi-5503
# 278                       Designing for Open Innovation   ame-4303
# 310                       Designing for Open Innovation   ame-5303
# 413                    Anthropology of Diet & Nutrition  anth-4183
# 618            Design X - Comprehensive Architecture II  arch-5055
# 649            Design IX - Comprehensive Architecture I  arch-5955
# 654             Design X- Comprehensive Architecture II  arch-6056
# 668             Design IX- Comprehensive Architecture I  arch-6956
# 1044                MBA Professional Development-Part A  b_ad-5100
# 1053                MBA Professional Development-Part B  b_ad-5200
# 1058                      Business Consulting Practicum  b_ad-5822
# 2397                                    Econometrics IV  econ-6373
# 2445                      Innovation in Student Affairs  edah-5493
# 2990                                Advanced Assessment  edsp-5183
# 3371  Issues in Contemporary Theory and Cultural Stu...  engl-6113
# 3400      Disruptive and Innovative Technology Ideation  engr-4023
# 3401                   Lincoln, Leadership & Innovation  engr-4051
# 3471                      Innovation & Entrepreneurship   ent-2113
# 3474                         Corporate Entrepreneurship   ent-3123
# 3476                            Entrepreneurial Process   ent-3203
# 3477                            New Product Development   ent-3413
# 3755                               The Language of Maps  geog-1113
# 3777                     Geography of Natural Resources  geog-3563
# 4108             Introduction to Organizational Studies   h_r-3203
# 4194                        Women, Work, and the Family   h_r-5713
# 4399                              The Revolutionary Era  hist-3093
# 5116                                     Special Topics   jmc-4970
# 5324  Transactional Law Practicum II: Law of Innovation   law-5743
# 5536        Adapting To Changing Marketing Environments  lsal-3533
# 5545            Case Studies in Social Entrepreneurship  lsal-4643
# 6284                            New Product Development   mkt-3413
# 7519        Leadership Theories, Research, and Practice   psy-6713

# %%
search_courses('computer programming')
# Out:
# 12 courses found
#
# From the following 6 departments: ['ame' 'c_s' 'gis' 'metr' 'mis' 'pbio']
#
# Would you like to save the result to a csv? n
#
#
# Did not save results to csv, but preview is available below.
#               Credits Departments  \
# 246   2 Credit Hours.         ame
# 248   3 Credit Hours.         ame
# 271   3 Credit Hours.         ame
# 1282   1 Credit Hour.         c_s
# 1313  0 Credit Hours.         c_s
# 4002  3 Credit Hours.         gis
# 4014  3 Credit Hours.         gis
# 6088  3 Credit Hours.        metr
# 6122  3 Credit Hours.        metr
# 6220  3 Credit Hours.         mis
# 7188  3 Credit Hours.        pbio
# 7208  3 Credit Hours.        pbio
#
#                                             Description Number  \
# 246   Prerequisite:MATH 1823or1914or concurrent enro...   2402
# 248   Prerequisite:PHYS 2514;MATH 1823or1914;MATH 24...   2623
# 271   Prerequisite: senior standing in an Engineerin...   4193
# 1282  Prerequisite: (MATH 1523or equivalent or concu...   1321
# 1313  Prerequisite: Permission of Instructor. Prepar...   4410
# 4002  (Slashlisted withGIS 5733; Crosslisted withPBI...   4733
# 4014  (Slashlisted withGIS 4733; Crosslisted withPBI...   5733
# 6088  Prerequisite:METR 1313. The basics principles ...   4323
# 6122  Prerequisite: Mathematics 4733 or 4753, comput...   5323
# 6220  Prerequisite: student must have been approved ...   3213
# 7188  (Slashlisted withPBIO 5733; Crosslisted withGI...   4733
# 7208  (Slashlisted withPBIO 4733; Crosslisted withGI...   5733
#
#                                       Title  Unique_ID
# 246                   Engineering Computing   ame-2402
# 248                    Circuits and Sensors   ame-2623
# 271   Introduction to Computer Aided Design   ame-4193
# 1282                   Java for Programmers   c_s-1321
# 1313                Programming Competition   c_s-4410
# 4002           Environmental Remote Sensing   gis-4733
# 4014           Environmental Remote Sensing   gis-5733
# 6088      Weather Simulation With Computers  metr-4323
# 6122                 Time Series Analysis I  metr-5323
# 6220                 Business Data Analysis   mis-3213
# 7188           Environmental Remote Sensing  pbio-4733
# 7208           Environmental Remote Sensing  pbio-5733

# %%
search_courses('data')
# Out:
# 256 courses found
#
# From the following 64 departments: ['acct' 'ame' 'anth' 'arch' 'art' 'astr' 'avia' 'b_ad' 'biol' 'bme' 'c_s'
#  'cees' 'ch_e' 'chem' 'cns' 'comm' 'dsa' 'eacs' 'ece' 'econ' 'edah' 'edec'
#  'eden' 'edlt' 'edsp' 'eipt' 'emba' 'g_e' 'geog' 'geol' 'gis' 'gphy'
#  'grad' 'h_r' 'hes' 'i_d' 'ise' 'jmc' 'l_a' 'ling' 'lis' 'lsal' 'lscj'
#  'lsis' 'lstd' 'math' 'mbio' 'metr' 'mgt' 'mis' 'mit' 'mkt' 'mued' 'npng'
#  'odyn' 'p_e' 'p_sc' 'pbio' 'phch' 'psy' 'rcpl' 's_wk' 'soc' 'tcom']
#
# Would you like to save the result to a csv? n
#
#
# Did not save results to csv, but preview is available below.
#                 Credits Departments  \
# 123     3 Credit Hours.        acct
# 250     2 Credit Hours.         ame
# 422     3 Credit Hours.        anth
# 424     3 Credit Hours.        anth
# 437     3 Credit Hours.        anth
# 438     3 Credit Hours.        anth
# 440     3 Credit Hours.        anth
# 441     3 Credit Hours.        anth
# 452     3 Credit Hours.        anth
# 475     3 Credit Hours.        anth
# 487     3 Credit Hours.        anth
# 499     3 Credit Hours.        anth
# 503     3 Credit Hours.        anth
# 506     3 Credit Hours.        anth
# 527   1-3 Credit Hours.        anth
# 532     3 Credit Hours.        anth
# 580     6 Credit Hours.        arch
# 606     3 Credit Hours.        arch
# 644     3 Credit Hours.        arch
# 715     3 Credit Hours.         art
# 952     3 Credit Hours.        astr
# 992     3 Credit Hours.        avia
# 1048    2 Credit Hours.        b_ad
# 1115    3 Credit Hours.        biol
# 1121    2 Credit Hours.        biol
# 1122     1 Credit Hour.        biol
# 1144    3 Credit Hours.        biol
# 1145    3 Credit Hours.        biol
# 1155    3 Credit Hours.        biol
# 1169    3 Credit Hours.        biol
# ...                 ...         ...
# 6279    3 Credit Hours.         mkt
# 6503    2 Credit Hours.        mued
# 6849    3 Credit Hours.        npng
# 6870    3 Credit Hours.        odyn
# 6881    3 Credit Hours.        odyn
# 6961    3 Credit Hours.         p_e
# 6988    3 Credit Hours.        p_sc
# 7013    3 Credit Hours.        p_sc
# 7170    3 Credit Hours.        pbio
# 7188    3 Credit Hours.        pbio
# 7208    3 Credit Hours.        pbio
# 7245    3 Credit Hours.        phch
# 7450    3 Credit Hours.         psy
# 7452    3 Credit Hours.         psy
# 7457    4 Credit Hours.         psy
# 7499    3 Credit Hours.         psy
# 7500    3 Credit Hours.         psy
# 7526  1-6 Credit Hours.         psy
# 7535    3 Credit Hours.        rcpl
# 7551    3 Credit Hours.        rcpl
# 7555    2 Credit Hours.        rcpl
# 7556    3 Credit Hours.        rcpl
# 7674    3 Credit Hours.        s_wk
# 7688    3 Credit Hours.        s_wk
# 7701    3 Credit Hours.        s_wk
# 7788    3 Credit Hours.         soc
# 7789    3 Credit Hours.         soc
# 7848    3 Credit Hours.         soc
# 7854    3 Credit Hours.         soc
# 7955    3 Credit Hours.        tcom
#
#                                             Description Number  \
# 123   Prerequisite: Student must be approved for deg...   3353
# 250   Prerequisite: 2113 or Engineering 2113; 3143 o...   3112
# 422   Prerequisite: junior standing or 3 hours of AN...   4343
# 424   Prerequisite: junior standing or 3 hours of AN...   4383
# 437   Prerequisite:DMAT 0123or satisfactory score on...   4683
# 438   Prerequisite: junior standing or 3 hours of AN...   4713
# 440   Prerequisite: junior standing or 3 hours of AN...   4743
# 441   Prerequisite:ANTH 3113orANTH 3930or permission...   4763
# 452   Prerequisite:ANTH 3203or permission of instruc...   4943
# 475   Prerequisite: graduate standing. Survey of eth...   5213
# 487   Prerequisites: graduate standing. Explores how...   5353
# 499   Prerequisite: graduate standing. Introduces th...   5593
# 503   Prerequisite: 5623 or permission of instructor...   5633
# 506   Prerequisite: Graduate standing. The goal of t...   5693
# 527   1 to 3 hours. May be repeated; maximum credit ...   5990
# 532   Prerequisite: graduate standing. Survey of the...   6643
# 580   Prerequisite:ARCH 2463,ARCH 2456,ARCH 2343, an...   3556
# 606   (Slashlisted withARCH 5773) Prerequisite: seni...   4773
# 644   (Slashlisted withARCH 4773) Prerequisite: Grad...   5773
# 715   Prerequisite: Majors only;ATC 2823. Considerat...   3823
# 952   Prerequisite: 3113 or 4303 or permission of in...   5453
# 992   Prerequisite: junior standing. Students will b...   3923
# 1048  Prerequisite:B AD 5001and graduate standing. I...   5122
# 1115  Prerequisite: 1114 and 1121, or 1124, or Biolo...   2913
# 1121  (Crosslisted with PSY 3092) Prerequisite: juni...   3092
# 1122  Prerequisite:BIOL 3103or concurrent enrollment...   3101
# 1144  Prerequisite: ZOO/BIOL 1124, or ZOO/BIOL 1114a...   4053
# 1145  (Slashlisted withBIOL 5063) Prerequisite: two ...   4063
# 1155  (Slashlisted with 5353) Prerequisite: 1114 and...   4353
# 1169  (Slashlisted withBIOL 5753) Prerequisite:BIOL ...   4753
# ...                                                 ...    ...
# 6279  Prerequisite: Student must be approved for deg...   3053
# 6503  Prerequisite: graduate standing in music or mu...   6242
# 6849  Prerequisite:NPNG 2033and senior standing or p...   4503
# 6870  Prerequisite: graduate standing or permission ...   5163
# 6881  Prerequisite: 5153 or permission of instructor...   5333
# 6961  (Crosslisted with G E andGEOL 6283) Prerequisi...   6283
# 6988  (Crosslisted withSOC 3123) Prerequisite:SOC 11...   3123
# 7013  Prerequisite: departmental permission andP SC ...   3483
# 7170  (Crosslisted withMBIO 3673) Prerequisite:PBIO ...   3673
# 7188  (Slashlisted withPBIO 5733; Crosslisted withGI...   4733
# 7208  (Slashlisted withPBIO 4733; Crosslisted withGI...   5733
# 7245  Prerequisite:ENGL 1213orEXPO 1213; corequisite...   3313
# 7450  Prerequisite: 1113 and satisfactory score on t...   2113
# 7452  Students will learn to identify the parts and ...   2503
# 7457  Prerequisite:PSY 1113;PSY 2003orPSY 2113. Exam...   3114
# 7499  Prerequisite: 5703. Covers a variety of substa...   5723
# 7500  Prerequisite: 5703. Provides an overview of ho...   5733
# 7526  1 to 6 hours. Prerequisite: 5703 and permissio...   6960
# 7535  (Slashlisted withRCPL 5463) Prerequisite: juni...   4463
# 7551  (Slashlisted withRCPL 4463) Prerequisite: grad...   5463
# 7555  Prerequisite: Graduate standing. This is the s...   5522
# 7556  Prerequisite: Graduate standing. This is the f...   5523
# 7674  Prerequisite:DMAT 0123, MATH 0123, or satisfac...   2223
# 7688  Prerequisite:S WK 4083. Introduction to applie...   4093
# 7701  Prerequisite: graduate standing in Social Work...   5093
# 7788  (Crosslisted withP SC 3123) Prerequisite:SOC 1...   3123
# 7789  Prerequisite:SOC 1113and any General Education...   3133
# 7848  Prerequisite:SOC 5483or permission of instruct...   5683
# 7854  Prerequisite: graduate standing in Sociology o...   5823
# 7955  Prerequisite: Electrical and Computer Engineer...   5553
#
#                                                   Title  Unique_ID
# 123            Accounting Information Systems/Databases  acct-3353
# 250                                 Solid Mechanics Lab   ame-3112
# 422   The Archaeology of Belief: Religion and Cosmol...  anth-4343
# 424                Archaeological Origins of Inequality  anth-4383
# 437   Quantitative Data Analysis in the Social Scien...  anth-4683
# 438                Statistical Concepts in Anthropology  anth-4713
# 440                    Culture Contact in the New World  anth-4743
# 441   Archaeological Analysis: Methods, Theory and P...  anth-4763
# 452                  Human Osteology and Paleopathology  anth-4943
# 475                                Ethnographic Methods  anth-5213
# 487                  Archaeology of Religion and Belief  anth-5353
# 499    Spatial Methods and Technologies in Anthropology  anth-5593
# 503                   Descriptive Linguistic Methods II  anth-5633
# 506                         Thesis/Dissertation Writing  anth-5693
# 527                    Special Anthropological Problems  anth-5990
# 532              Methods in Living Populations Research  anth-6643
# 580                   Design V - Architectural Making I  arch-3556
# 606                Computational Design and Fabrication  arch-4773
# 644                Computational Design and Fabrication  arch-5773
# 715                        Concepts in Electronic Media   art-3823
# 952               Extragalactic Astronomy and Cosmology  astr-5453
# 992                      Aerospace Operational Research  avia-3923
# 1048               Quantitative Methods and Modeling II  b_ad-5122
# 1115                      Intro to Quantitative Biology  biol-2913
# 1121                         Animal Behavior Laboratory  biol-3092
# 1122                       Principles of Physiology Lab  biol-3101
# 1144                                Forensic Entomology  biol-4053
# 1145                                  Field Herpetology  biol-4063
# 1155                       Molecular Tech-Field Biology  biol-4353
# 1169              Molecular Evolution and Phylogenetics  biol-4753
# ...                                                 ...        ...
# 6279                                 Marketing Research   mkt-3053
# 6503           Quantitative Research in Music Education  mued-6242
# 6849                  Program Evaluation for Nonprofits  npng-4503
# 6870                   Applied Measurement and Analysis  odyn-5163
# 6881               Customer Service and Market Analysis  odyn-5333
# 6961                         Seismic Reservoir Modeling   p_e-6283
# 6988                                  Social Statistics  p_sc-3123
# 7013                                Campaign Management  p_sc-3483
# 7170                           Practical Bioinformatics  pbio-3673
# 7188                       Environmental Remote Sensing  pbio-4733
# 7208                       Environmental Remote Sensing  pbio-5733
# 7245                         Health Data and Statistics  phch-3313
# 7450                     Research Methods I: Statistics   psy-2113
# 7452                  Computing for Behavioral Sciences   psy-2503
# 7457  Research Methods II: Applications and Experime...   psy-3114
# 7499          Selection and Assessment in Organizations   psy-5723
# 7500  Techniques in Industrial and Organizational Ps...   psy-5733
# 7526  Research in Industrial and Organizational Psyc...   psy-6960
# 7535  Geographic Information Systems for Land Use Pl...  rcpl-4463
# 7551  Geographic Information Systems for Land Use Pl...  rcpl-5463
# 7555  Comprehensive RCPL Project: Reporting and Impl...  rcpl-5522
# 7556  Comprehensive RCPL Project: Research and Plan ...  rcpl-5523
# 7674                         Statistics for Social Work  s_wk-2223
# 7688      Undergraduate Social Work Research Methods II  s_wk-4093
# 7701                    Social Work Research Methods II  s_wk-5093
# 7788                                  Social Statistics   soc-3123
# 7789                         Methods of Social Research   soc-3133
# 7848  Categorical, Panel, and Advanced Statistical A...   soc-5683
# 7854                                  Social Demography   soc-5823
# 7955                      Telecommunications Technology  tcom-5553
#
# [256 rows x 6 columns]

# %%
#Loading libraries to do more analysis in python
import nltk, wordcloud, numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
from collections import Counter

nltk.download('punkt')
nltk.download('stopwords')  
nltk.download('vader_lexicon')

# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /Users/sclayton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sclayton/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/sclayton/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def most_freq_words(term):
    #Selecting data subsample
    data_courses = search_courses(term)
    
    # Cleaning Data
    # Making all lowercase
    data_courses.loc[:,'Description'] = data_courses.loc[:,'Description'].apply(lambda x: " ".join(x.lower() for x in x.split()))

    #Removing puncuation
    data_courses.loc[:,'Description'] = data_courses.loc[:,'Description'].str.replace('[^\w\s*]'," ")

    #Lemmatize strings
    wnl = nltk.stem.WordNetLemmatizer()
    #Need to do for different parts of speech
    data_courses.loc[:,'Description'] = data_courses.loc[:,'Description'].apply(lambda x: " ".join([wnl.lemmatize(x) for x in x.split()]))
    data_courses.loc[:,'Description'] = data_courses.loc[:,'Description'].apply(lambda x: " ".join([wnl.lemmatize(x, 'v') for x in x.split()]))

    #Removing stopwords
    stop = nltk.corpus.stopwords.words('english')
    stop.extend([term,'prerequisite','student','permission','stand','course','instructor','include','credit','may'])
    data_courses.loc[:,'Description'] = data_courses.loc[:,'Description'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

    #Get list of most frequent terms
    top_freq = pd.Series(' '.join(data_courses['Description']).split()).value_counts()[:50]
    
    #plot frequent words
    top_freq.plot(kind="bar", figsize=(20,10), fontsize=20)

# %%
most_freq_words('data')
# Out:
# 256 courses found
#
# From the following 64 departments: ['acct' 'ame' 'anth' 'arch' 'art' 'astr' 'avia' 'b_ad' 'biol' 'bme' 'c_s'
#  'cees' 'ch_e' 'chem' 'cns' 'comm' 'dsa' 'eacs' 'ece' 'econ' 'edah' 'edec'
#  'eden' 'edlt' 'edsp' 'eipt' 'emba' 'g_e' 'geog' 'geol' 'gis' 'gphy'
#  'grad' 'h_r' 'hes' 'i_d' 'ise' 'jmc' 'l_a' 'ling' 'lis' 'lsal' 'lscj'
#  'lsis' 'lstd' 'math' 'mbio' 'metr' 'mgt' 'mis' 'mit' 'mkt' 'mued' 'npng'
#  'odyn' 'p_e' 'p_sc' 'pbio' 'phch' 'psy' 'rcpl' 's_wk' 'soc' 'tcom']
#
# Would you like to save the result to a csv? n
#
#
# Did not save results to csv, but preview is available below.
# /Users/sclayton/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
most_freq_words('innovation|innovative')
# Out:
# 33 courses found
#
# From the following 19 departments: ['a_hi' 'ame' 'anth' 'arch' 'b_ad' 'econ' 'edah' 'edsp' 'engl' 'engr'
#  'ent' 'geog' 'h_r' 'hist' 'jmc' 'law' 'lsal' 'mkt' 'psy']
#
# Would you like to save the result to a csv? n
#
#
# Did not save results to csv, but preview is available below.
# /Users/sclayton/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
most_freq_words('digital')
# Out:
# 72 courses found
#
# From the following 26 departments: ['a_hi' 'afam' 'ame' 'arch' 'art' 'artc' 'atc' 'cas' 'cees' 'ch_e' 'ece'
#  'edrg' 'engl' 'engr' 'fms' 'geog' 'gis' 'hsci' 'jmc' 'lis' 'lscj' 'metr'
#  'mis' 'mutk' 'p_e' 'phys']
#
# Would you like to save the result to a csv? n
#
#
# Did not save results to csv, but preview is available below.
# /Users/sclayton/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
